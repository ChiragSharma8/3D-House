# %% [markdown]
# # Matching Bounds

# %%
import pandas as pd
import csv

'''def match_bounds(x,y):
    bbound = pd.read_csv("bounds.csv", index_col = 0)
    
    bbound.columns = ['left', 'bottom', 'right', 'top']
    bbound['left'] = bbound['left'].apply(lambda x: x[1:])
    bbound['left'] = bbound['left'].astype(float)
    bbound['bottom'] = bbound.astype(float)
    bbound['right'] = bbound.astype(float)
    bbound['top'] = bbound['top'].apply(lambda y: y[:-1])
    bbound['top'] = bbound['top'].astype(float)
    
    x = float(x)
    y = float(y)
    for i in bbound:
         if ((left< x < right) and (top < y < bottom)):
                return i
match_bounds(130021,216065)'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-0e1ef7dc1c5f> in <module>
#      18          if ((left< x < right) and (top < y < bottom)):
#      19                 return i
# ---> 20 match_bounds(130021,216065)
#
# <ipython-input-4-0e1ef7dc1c5f> in match_bounds(x, y)
#       5     bbound = pd.read_csv("bounds.csv", index_col = 0)
#       6
# ----> 7     bbound.columns = ['left', 'bottom', 'right', 'top']
#       8     bbound['left'] = bbound['left'].apply(lambda x: x[1:])
#       9     bbound['left'] = bbound['left'].astype(float)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# ...

# %%
 x = float(x)
    y = float(y)
    for i in :
        
        if ((left< x < right) and (top < y < bottom)) 
        elif ((left = x) and ())

# %%
xs = np.array([152253.90])
ys = np.array([212858.3915])

with rio.open(infile) as src:
    rows, cols = rio.transform.rowcol(src.transform, xs, ys)
    print (rows)
    print (cols)

# %%
# dictionary making and finding the tile name of coordinates
import rasterio as rio
bounds_test = {}

for i in range (1, 641):
    path = "/home/becode/lidar/K_15/DTM/GeoTIFF/" + str(i) + ".tif"
    dtm = rio.open(path) 
    bounds_test[i] = dtm.bounds
print(bounds_test)

for keys,values in bounds_test.items():
    left = values[0]
    bottom = values[1]
    right = values[2]
    top = values[3]
    
    x =130010 
    y =200020
    
    if (left < x < right) and (bottom < y < top):
        tile_number = keys
        print ('tile_number: ', tile_number)
# Out:
# {1: BoundingBox(left=130000.0, bottom=218000.0, right=131000.0, top=219000.0), 2: BoundingBox(left=130000.0, bottom=217000.0, right=131000.0, top=218000.0), 3: BoundingBox(left=130000.0, bottom=216000.0, right=131000.0, top=217000.0), 4: BoundingBox(left=130000.0, bottom=215000.0, right=131000.0, top=216000.0), 5: BoundingBox(left=130000.0, bottom=214000.0, right=131000.0, top=215000.0), 6: BoundingBox(left=130000.0, bottom=213000.0, right=131000.0, top=214000.0), 7: BoundingBox(left=130000.0, bottom=212000.0, right=131000.0, top=213000.0), 8: BoundingBox(left=130000.0, bottom=211000.0, right=131000.0, top=212000.0), 9: BoundingBox(left=130000.0, bottom=210000.0, right=131000.0, top=211000.0), 10: BoundingBox(left=130000.0, bottom=209000.0, right=131000.0, top=210000.0), 11: BoundingBox(left=130000.0, bottom=208000.0, right=131000.0, top=209000.0), 12: BoundingBox(left=130000.0, bottom=207000.0, right=131000.0, top=208000.0), 13: BoundingBox(left=130000.0, bottom=206000.0, right=1310
# ...

# %%
BoundingBox(left=130000.0, bottom=200000.0, right=131000.0, top=201000.0)-----19

# %%
crop
